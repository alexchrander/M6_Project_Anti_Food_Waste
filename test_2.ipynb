# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_parquet("/Users/anderssonderby/PythonBDS/8th_semester/Data_Engineering_and_MLOPS_in_Business/M6_Project_Anti_Food_Waste/data/features/features_20260426.parquet")
df.head()
# Out:
#                                            unique_id  \
# 0  1a3a385a-f1e4-4b43-bc65-aa4190a0925b_2007182_2...
# 1  1a3a385a-f1e4-4b43-bc65-aa4190a0925b_2007205_2...
# 2  1a3a385a-f1e4-4b43-bc65-aa4190a0925b_2007212_2...
# 3  1a3a385a-f1e4-4b43-bc65-aa4190a0925b_2007229_2...
# 4  1a3a385a-f1e4-4b43-bc65-aa4190a0925b_2007243_2...
#
#                                store_id           store_name store_brand  \
# 0  1a3a385a-f1e4-4b43-bc65-aa4190a0925b  føtex Food Hasseris      foetex
# 1  1a3a385a-f1e4-4b43-bc65-aa4190a0925b  føtex Food Hasseris      foetex
# 2  1a3a385a-f1e4-4b43-bc65-aa4190a0925b  føtex Food Hasseris      foetex
# 3  1a3a385a-f1e4-4b43-bc65-aa4190a0925b  føtex Food Hasseris      foetex
# 4  1a3a385a-f1e4-4b43-bc65-aa4190a0925b  føtex Food Hasseris      foetex
#
#   store_city  store_lat  store_lng         store_street store_zip  \
# 0    Aalborg    57.0359    9.88336  Hasseris Bymidte 29      9000
# 1    Aalborg    57.0359    9.88336  Hasseris Bymidte 29      9000
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7773 entries, 0 to 7772
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   unique_id                  7773 non-null   object
#  1   store_id                   7773 non-null   object
#  2   store_name                 7773 non-null   object
#  3   store_brand                7773 non-null   object
#  4   store_city                 7773 non-null   object
#  5   store_lat                  7773 non-null   float64
#  6   store_lng                  7773 non-null   float64
#  7   store_street               7773 non-null   object
#  8   store_zip                  7773 non-null   object
#  9   store_country              7773 non-null   object
#  10  product_ean                7773 non-null   object
#  11  product_description        7773 non-null   object
#  12  product_image              7180 non-null   object
# ...

# %%
df['category_level1_da'].value_counts()
# Out:
# category_level1_da
# Mejeri & køl       3943
# Brød & kager       2102
# Kød & fisk          937
# Unknown             595
# Drikkevarer         164
# Frost                22
# Personlig pleje       8
# Kolonial              2
# Name: count, dtype: int64

# %%
dairy = df[df['category_level1_da'] == 'Mejeri & køl']
dairy = dairy[['product_description', 'offer_original_price', 'offer_percent_discount', 'initial_stock', 'final_stock', 'sell_through_rate', 'hours_until_close', 'offer_start_dayofweek', 'is_weight_based', 'category_level2_da']]
print(dairy.shape)
# Out:
# (3943, 10)

# %%
dairy.head()
# Out:
#                product_description  offer_original_price  \
# 2        MØRBRADGRYDE GODT BEGYNDT                 59.95
# 3      MØRBRAD M KAR. GODT BEGYNDT                 89.95
# 25                  GB URTEKYLLING                 59.95
# 27     MØRBRAD M KAR. GODT BEGYNDT                 89.95
# 28  MØRBRAD M. GRATIN GODT BEGYNDT                 89.95
#
#     offer_percent_discount  initial_stock  final_stock  sell_through_rate  \
# 2                    24.94       0.093781     0.093781           0.000000
# 3                    38.85       0.092245     0.092245           0.000000
# 25                   33.28       0.093219     0.093219           0.000000
# 27                   44.41       0.094189     0.093219           0.010298
# 28                   27.74       0.094747     0.093219           0.016127
#
#     hours_until_close  offer_start_dayofweek  is_weight_based  \
# 2           10.883333                      2             True
# ...

# %%
print(dairy['is_weight_based'].value_counts())
print(dairy['category_level2_da'].unique())
# Out:
# is_weight_based
# False    3882
# True       61
# Name: count, dtype: int64
# ['Færdigretter på køl' 'Mejeri' 'Bacon, pølser & toppings' 'Pålæg'
#  'Tapas & specialiteter' 'Fersk dej & pandekager' 'Saucer & dressinger'
#  'Kartoffeltilbehør' 'Frisk pasta' 'Æg & gær']

# %%
dairy.describe()
# Out:
#        offer_original_price  offer_percent_discount  initial_stock  \
# count           3943.000000             3943.000000    3943.000000
# mean              27.133018               41.332488       7.093407
# std               17.385194               16.568399      19.861863
# min                1.500000                7.690000       0.092245
# 25%               16.950000               25.540000       1.000000
# 50%               22.090000               39.980000       3.000000
# 75%               32.490000               51.500000       6.000000
# max              275.000000               92.280000     447.000000
#
#        final_stock  sell_through_rate  hours_until_close  \
# count  3943.000000        3943.000000        3943.000000
# mean      4.009178           0.294958           9.217690
# std      13.759849           0.326099           4.621031
# min       0.092245           0.000000           0.000000
# 25%       1.000000           0.000000           5.983333
# ...

# %%
dairy['product_description'].nunique()
# Out:
# 1108

# %%
dairy['offer_percent_discount'].hist(bins=20)
plt.title('Distribution of Offer Percent Discount')
plt.xlabel('Offer Percent Discount')
plt.ylabel('Frequency')
plt.show()

# %%
many_dairy = dairy[dairy['initial_stock'] > 30]
many_dairy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 126 entries, 218 to 7443
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_description     126 non-null    object
#  1   offer_original_price    126 non-null    float64
#  2   offer_percent_discount  126 non-null    float64
#  3   initial_stock           126 non-null    float64
#  4   final_stock             126 non-null    float64
#  5   sell_through_rate       126 non-null    float64
#  6   hours_until_close       126 non-null    float64
#  7   offer_start_dayofweek   126 non-null    int32
#  8   is_weight_based         126 non-null    bool
#  9   category_level2_da      126 non-null    object
# dtypes: bool(1), float64(6), int32(1), object(2)
# memory usage: 9.5+ KB

# %%
many_dairy.head(20)
# Out:
#                 product_description  offer_original_price  \
# 218             ØKOLOGISK SMØR ARLA                 29.65
# 219           ØKO SMØRBAR KÆRGÅRDEN                 31.85
# 247          KAKAOMÆLK DÅSE MATILDE                 10.95
# 252           ØKO SMØRBAR KÆRGÅRDEN                 31.85
# 255       PISKEFLØDE 36% KAROLINE'S                 29.95
# 827             HØNSESALAT GRAASTEN                 10.00
# 829       RULLEPØLSE STEFF HOULBERG                  9.00
# 830     HAMBURGERRYG STEFF HOULBERG                  9.00
# 858            ØKO SKUMMETMÆLK ARLA                 12.95
# 873       ØKO SKUMMETMÆLK LØGISMOSE                 13.95
# 875   MOUSSE M/ VANILJE PROTEIN LAB                 12.00
# 990           KYLLINGEBRYST MINIMUM                 16.95
# 992           HONNINGSKINKE MINIMUM                 16.95
# 993     STEGT KYLLINGEBRYST MINIMUM                 14.36
# 1093              SDJ. SALAMI LAMPE                 29.00
# ...

# %%
many_dairy['sell_through_rate'].hist(bins=10)
plt.title('Distribution of Sell Through Rate for Dairy Products with Initial Stock > 30')
plt.xlabel('Sell Through Rate')
plt.ylabel('Frequency')
plt.show()

# %%
many_dairy[many_dairy['sell_through_rate'] > 0.5].head()
# Out:
#            product_description  offer_original_price  offer_percent_discount  \
# 218        ØKOLOGISK SMØR ARLA                 29.65                   49.41
# 247     KAKAOMÆLK DÅSE MATILDE                 10.95                   54.34
# 829  RULLEPØLSE STEFF HOULBERG                  9.00                   66.67
# 858       ØKO SKUMMETMÆLK ARLA                 12.95                   22.78
# 873  ØKO SKUMMETMÆLK LØGISMOSE                 13.95                   21.15
#
#      initial_stock  final_stock  sell_through_rate  hours_until_close  \
# 218          168.0         24.0           0.857143          11.250000
# 247          247.0        115.0           0.534413          15.383333
# 829           40.0         15.0           0.625000           0.000000
# 858           89.0          3.0           0.966292           5.150000
# 873           53.0          1.0           0.981132           0.000000
#
#      offer_start_dayofweek  is_weight_based category_level2_da
# ...

# %%
# Sort by sell through rate
dairy_sorted = many_dairy.sort_values(by='sell_through_rate', ascending=False)
dairy_sorted.head()
# Out:
#               product_description  offer_original_price  \
# 3424             LETMÆLK EGELYKKE                 10.95
# 4705        3X ESPRESSO STARBUCKS                 19.95
# 3528                 SØDMÆLK ARLA                 13.50
# 873     ØKO SKUMMETMÆLK LØGISMOSE                 13.95
# 993   STEGT KYLLINGEBRYST MINIMUM                 14.36
#
#       offer_percent_discount  initial_stock  final_stock  sell_through_rate  \
# 3424                   26.94          193.0          1.0           0.994819
# 4705                   49.87           72.0          1.0           0.986111
# 3528                   25.93          127.0          2.0           0.984252
# 873                    21.15           53.0          1.0           0.981132
# 993                    30.36           46.0          1.0           0.978261
#
#       hours_until_close  offer_start_dayofweek  is_weight_based  \
# 3424          12.350000                      1            False
# ...

# %%
df_2 = pd.read_parquet("/Users/anderssonderby/PythonBDS/8th_semester/Data_Engineering_and_MLOPS_in_Business/M6_Project_Anti_Food_Waste/data/dataset/labelled_offers_20260426.parquet")
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7773 entries, 0 to 7772
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   unique_id                  7773 non-null   object
#  1   store_id                   7773 non-null   object
#  2   store_name                 7773 non-null   object
#  3   store_brand                7773 non-null   object
#  4   store_city                 7773 non-null   object
#  5   store_lat                  7773 non-null   float64
#  6   store_lng                  7773 non-null   float64
#  7   store_street               7773 non-null   object
#  8   store_zip                  7773 non-null   object
#  9   store_country              7773 non-null   object
#  10  product_ean                7773 non-null   object
#  11  product_description        7773 non-null   object
#  12  product_image              7180 non-null   object
# ...
